# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="10%">
#             <img src="in_class.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b>Inclass - Lab<br> (Day 2)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Table of Content
# 1. **[Data Structures with Examples](#Data_Structures)**
# 2. **[Create and Manipulate the DataFrames](#create_manipulate)**
# 3. **[Sort](#sorting)**
# 4. **[Rank](#ranking)**

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id='Data_Structures'></a>
# ## 1. Data Structures with Examples:

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Write a program to create a dataframe from list of lists
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the below nested list:**<br>
#
#         data = [['Joy', 21], ['Mia', 15], ['Sam', 14]]

# %%
# type your code here
import pandas as pd

data = [['Joy', 21], ['Mia', 15], ['Sam', 14]]
dataFrame = pd.DataFrame(data)
print(dataFrame)
# Out:
#      0   1
# 0  Joy  21
# 1  Mia  15
# 2  Sam  14

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Extract the second word from the given string
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the below string:**<br>
#
#     sentence = 'Be confident and be yourself'

# %%
# type your code here
sentence = 'Be confident and be yourself'
print(sentence.split(" ")[1])
# Out:
# confident

# %% [markdown]
# <a id='create_manipulate'></a>
# ## 2. Create and Manipulate the DataFrames:

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. Split the 'Name' column into two separate columns as First_Name and Last_Name </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# </tr>
# <tr>
# <td>Emma Larter</td>
# <td>3200</td>
# </tr>
# <tr>
# <td>Mia Junior</td>
# <td>4500</td>
# </tr>
# <tr>
# <td>Sophia Depp</td>
# <td>3600</td>
# </tr>
# <tr>
# <td>James Smith</td>
# <td>5596</td>
# </tr>
#
# </table>

# %%
# type your code here

salList = [3200,4500,3600,5596]
dataFrame1 = pd.DataFrame({'Name': ['Emma Larter','Mia Junior','Sophia Depp','James Smith'],
                         'Salary':salList})

print("======================Input======================")
print(dataFrame1)
listOfNewColumn = dataFrame1.Name.str.split(expand=True)
dataFrame1.insert(0, 'First_Name', listOfNewColumn[0])
dataFrame1.insert(1, 'Last_Name', listOfNewColumn[1])
dataFrame1.drop(labels='Name',axis=1,inplace=True)
print("\n\n\n After adding two new columns : \n======================Output======================\n\n", dataFrame1)
# Out:
# ======================Input======================
#           Name  Salary
# 0  Emma Larter    3200
# 1   Mia Junior    4500
# 2  Sophia Depp    3600
# 3  James Smith    5596
#
#
#
#  After adding two new columns :
# ======================Output======================
#
#    First_Name Last_Name  Salary
# 0       Emma    Larter    3200
# 1        Mia    Junior    4500
# 2     Sophia      Depp    3600
# 3      James     Smith    5596

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4. Select the rows from below dataframe where marks are less than 60 </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Marks</th>
# </tr>
# <tr>
# <td>John</td>
# <td>90</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>50</td>
# </tr>
# <tr>
# <td>Jonny</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>55</td>
# </tr>
#
# </table>

# %%
# type your code here
nameList = ['John','Robert','Johny','Mia']
marksList = [90,50,89,55]
dataFrame2 = pd.DataFrame({'Name': nameList,
                         'Marks':marksList})
print(dataFrame2[dataFrame2.Marks < 60])
# Out:
#      Name  Marks
# 1  Robert     50
# 3     Mia     55

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Write a program to select the rows where the sales are higher than 60000 for Mumbai </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
storeList = ['A','B','A','C','D','A','D','A','C','B']
locationList = ['Mumbai','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune']
salesList = [40000,45000,50000,90000,89000,87000,85000,780000,89000,70000]
dataFrame3 = pd.DataFrame({'Store': storeList,
                         'Location':locationList,
                          'Sales':salesList})
print("==========DataFrame==========")
print(dataFrame3)
print("\n\n\n==========Output==========")
print(dataFrame3[(dataFrame3.Location=='Mumbai') & (dataFrame3.Sales > 60000)])
# Out:
# ==========DataFrame==========
#   Store   Location   Sales
# 0     A     Mumbai   40000
# 1     B       Pune   45000
# 2     A  Hyderabad   50000
# 3     C     Mumbai   90000
# 4     D       Pune   89000
# 5     A      Delhi   87000
# 6     D  Hyderabad   85000
# 7     A       Pune  780000
# 8     C     Mumbai   89000
# 9     B       Pune   70000
#
#
#
# ==========Output==========
#   Store Location  Sales
# 3     C   Mumbai  90000
# 8     C   Mumbai  89000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. Write a program to select stores located in Hyderabad</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
print("\n==========Output==========")
print(dataFrame3[(dataFrame3.Location=='Hyderabad')])
# Out:
# ==========Output==========
#   Store   Location  Sales
# 2     A  Hyderabad  50000
# 6     D  Hyderabad  85000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Write a program to replace the 'Store' column with the values A, B, C, and D with Store_A,  Store_B, Store_C and Store_D respectively </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
storeList = ['A','B','A','C','D','A','D','A','C','B']
locationList = ['Mumbai','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune']
salesList = [40000,45000,50000,90000,89000,87000,85000,780000,89000,70000]
df3 = pd.DataFrame({'Store': storeList,
                         'Location':locationList,
                          'Sales':salesList})

df3['Store'] = df3['Store'].replace(['A'],'Store_A')
df3['Store'] = df3['Store'].replace(['B'],'Store_B')
df3['Store'] = df3['Store'].replace(['C'],'Store_C')
df3['Store'] = df3['Store'].replace(['D'],'Store_D')
df3
# Out:
#      Store   Location   Sales
# 0  Store_A     Mumbai   40000
# 1  Store_B       Pune   45000
# 2  Store_A  Hyderabad   50000
# 3  Store_C     Mumbai   90000
# 4  Store_D       Pune   89000
# 5  Store_A      Delhi   87000
# 6  Store_D  Hyderabad   85000
# 7  Store_A       Pune  780000
# 8  Store_C     Mumbai   89000
# 9  Store_B       Pune   70000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Create a dataframe in pandas using the given list.
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the below list**
#
#         city = ['Delhi', 'Mumbai', 'Chennai', 'Kolkata']

# %%
# type your code here
city = ['Delhi', 'Mumbai', 'Chennai', 'Kolkata']
cityDF = pd.DataFrame(city)
cityDF
# Out:
#          0
# 0    Delhi
# 1   Mumbai
# 2  Chennai
# 3  Kolkata

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Save a given dataframe to a csv file
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
storeList = ['A','B','A','C','D','A','D','A','C','B']
locationList = ['Mumbai','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune']
salesList = [40000,45000,50000,90000,89000,87000,85000,780000,89000,70000]
dataFrame3 = pd.DataFrame({'Store': storeList,
                         'Location':locationList,
                          'Sales':salesList})
print("==========DataFrame==========")
print(dataFrame3)
dataFrame3.to_csv('file1.csv')
# Out:
# ==========DataFrame==========
#   Store   Location   Sales
# 0     A     Mumbai   40000
# 1     B       Pune   45000
# 2     A  Hyderabad   50000
# 3     C     Mumbai   90000
# 4     D       Pune   89000
# 5     A      Delhi   87000
# 6     D  Hyderabad   85000
# 7     A       Pune  780000
# 8     C     Mumbai   89000
# 9     B       Pune   70000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Find the maximum sales for each store
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
storeList = ['A','B','A','C','D','A','D','A','C','B']
locationList = ['Mumbai','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune']
salesList = [40000,45000,50000,90000,89000,87000,85000,780000,89000,70000]
dataFrame3 = pd.DataFrame({'Store': storeList,
                         'Location':locationList,
                          'Sales':salesList})
groupByStore = dataFrame3.groupby(by="Store").max()
groupByStore
# Out:
#       Location   Sales
# Store
# A         Pune  780000
# B         Pune   70000
# C       Mumbai   90000
# D         Pune   89000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>11. Write a program to select all columns, except the 'Location' from the given dataframe
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
dataFrame4 = dataFrame3[dataFrame3.columns.difference(['Location'],sort=False)]
dataFrame4
# Out:
#   Store   Sales
# 0     A   40000
# 1     B   45000
# 2     A   50000
# 3     C   90000
# 4     D   89000
# 5     A   87000
# 6     D   85000
# 7     A  780000
# 8     C   89000
# 9     B   70000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>12. Write a program to insert a given column at the second position in a dataframe
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Age</th>
# </tr>
# <tr>
# <td>Emma Larter</td>
# <td>34</td>
# </tr>
# <tr>
# <td>Mia Junior</td>
# <td>59</td>
# </tr>
# <tr>
# <td>Sophia Depp</td>
# <td>32</td>
# </tr>
# <tr>
# <td>James Smith</td>
# <td>40</td>
# </tr>
#
# </table>
#
# **Add the variable 'Salary' as second column**<br>
#
#             Salary = [35000, 24000, 55000, 40000]

# %%
# type your code here
nameList = ['Emma Larter','Mia Junior','Sophia Depp','James Smith']
ageList = [34,59,32,40]
df4 = pd.DataFrame({'Name': nameList,
                         'Age':ageList})

Salary = [35000, 24000, 55000, 40000]
df4.insert(1, "Salary", Salary, True)
print(df4)
# Out:
#           Name  Salary  Age
# 0  Emma Larter   35000   34
# 1   Mia Junior   24000   59
# 2  Sophia Depp   55000   32
# 3  James Smith   40000   40

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>13. Write a program to get the third observation of the given dataframe
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Age</th>
# </tr>
# <tr>
# <td>Emma Larter</td>
# <td>34</td>
# </tr>
# <tr>
# <td>Mia Junior</td>
# <td>59</td>
# </tr>
# <tr>
# <td>Sophia Depp</td>
# <td>32</td>
# </tr>
# <tr>
# <td>James Smith</td>
# <td>40</td>
# </tr>
# </table>

# %%
# type your code here
nameList = ['Emma Larter','Mia Junior','Sophia Depp','James Smith']
ageList = [34,59,32,40]
df5 = pd.DataFrame({'Name': nameList,'Age':ageList})
df5.head(3)
# Out:
#           Name  Age
# 0  Emma Larter   34
# 1   Mia Junior   59
# 2  Sophia Depp   32

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>14. Write a program to create a dataframe from the provided lists</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the following lists to create your arrays:**
#
#             columns = ["Science", "Maths", "English"]
#
#             marks = [[55, 78, 88], [93, 63, 83],[94, 74, 64]]
#
# **Hint:** Convert the list marks into an array

# %%
# type your code here
import numpy as np
columnsList = np.array(["Science", "Maths", "English"])
marksArray = np.array([[55, 78, 88], [93, 63, 83],[94, 74, 64]])
df6 = pd.DataFrame(list(zip(columnsList,marksArray)),
               columns =['Subject', 'Marks'])
df6
# Out:
#    Subject         Marks
# 0  Science  [55, 78, 88]
# 1    Maths  [93, 63, 83]
# 2  English  [94, 74, 64]

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>15. Write a program to count total sales per store </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
storeList = ['A','B','A','C','D','A','D','A','C','B']
locationList = ['Mumbai','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune']
salesList = [40000,45000,50000,90000,89000,87000,85000,780000,89000,70000]
dataFrame3 = pd.DataFrame({'Store': storeList,
                         'Location':locationList,
                          'Sales':salesList})
groupByStore = dataFrame3.groupby(by="Store")['Sales'].agg('sum')
groupByStore
# Out:
# Store
# A    957000
# B    115000
# C    179000
# D    174000
# Name: Sales, dtype: int64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>16. Write a program to count the top five commonly used words in a list
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the below list:**<br>
#
#             words_list = ['words', 'will', 'where', 'shall', 'we', 'will', 'shall', 'we', 'words', 'where', 'shall',
#                         'will', 'there', 'wow', 'should', 'shall', 'we', 'where', 'should', 'where', 'will',
#                         'there', 'now', 'where', 'we', 'will', 'where', 'should', 'will', 'where']

# %%
# type your code here
import collections as col
words_list = ['words', 'will', 'where', 'shall', 'we', 'will', 'shall', 'we', 'words', 'where', 'shall',
                    'will', 'there', 'wow', 'should', 'shall', 'we', 'where', 'should', 'where', 'will', 
                    'there', 'now', 'where', 'we', 'will', 'where', 'should', 'will', 'where']
mostcommonwords = col.Counter(words_list).most_common(5)
print(mostcommonwords)
# Out:
# [('where', 7), ('will', 6), ('shall', 4), ('we', 4), ('should', 3)]

# %% [markdown]
# <a id='sorting'></a>
# ## 3. Sort

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. Write a program to sort the dataframe by 'Sales' in ascending order
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
storeList = ['A','B','A','C','D','A','D','A','C','B']
locationList = ['Mumbai','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune']
salesList = [40000,45000,50000,90000,89000,87000,85000,780000,89000,70000]
df7 = pd.DataFrame({'Store': storeList,
                         'Location':locationList,
                          'Sales':salesList})
dfnew = df7.sort_values(by=['Sales'])
dfnew
# Out:
#   Store   Location   Sales
# 0     A     Mumbai   40000
# 1     B       Pune   45000
# 2     A  Hyderabad   50000
# 9     B       Pune   70000
# 6     D  Hyderabad   85000
# 5     A      Delhi   87000
# 4     D       Pune   89000
# 8     C     Mumbai   89000
# 3     C     Mumbai   90000
# 7     A       Pune  780000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. Write a program to sort the dataframe by 'Store' in ascending order and by 'Sales' in descending order simultaneously
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
storeList = ['A','B','A','C','D','A','D','A','C','B']
locationList = ['Mumbai','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune']
salesList = [40000,45000,50000,90000,89000,87000,85000,780000,89000,70000]
df7 = pd.DataFrame({'Store': storeList,
                         'Location':locationList,
                          'Sales':salesList})
dfnew = df7.sort_values(by=['Store','Sales'], ascending=[True, False])
dfnew
# Out:
#   Store   Location   Sales
# 7     A       Pune  780000
# 5     A      Delhi   87000
# 2     A  Hyderabad   50000
# 0     A     Mumbai   40000
# 9     B       Pune   70000
# 1     B       Pune   45000
# 3     C     Mumbai   90000
# 8     C     Mumbai   89000
# 4     D       Pune   89000
# 6     D  Hyderabad   85000

# %% [markdown]
# <a id='ranking'></a>
# ## 4. Rank

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>19. Create a column 'Rank_sales' which contains the rank of each store based on sales of the product in ascending order
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
storeList = ['A','B','A','C','D','A','D','A','C','B']
locationList = ['Mumbai','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune']
salesList = [40000,45000,50000,90000,89000,87000,85000,780000,89000,70000]
df8 = pd.DataFrame({'Store': storeList,
                         'Location':locationList,
                          'Sales':salesList})
df8['Rank_Sales'] = df8['Sales'].rank(ascending=True)
df8
# Out:
#   Store   Location   Sales  Rank_Sales
# 0     A     Mumbai   40000         1.0
# 1     B       Pune   45000         2.0
# 2     A  Hyderabad   50000         3.0
# 3     C     Mumbai   90000         9.0
# 4     D       Pune   89000         7.5
# 5     A      Delhi   87000         6.0
# 6     D  Hyderabad   85000         5.0
# 7     A       Pune  780000        10.0
# 8     C     Mumbai   89000         7.5
# 9     B       Pune   70000         4.0

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>20. Rank the dataframe in descending order of sales by each store
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
storeList = ['A','B','A','C','D','A','D','A','C','B']
locationList = ['Mumbai','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune']
salesList = [40000,45000,50000,90000,89000,87000,85000,780000,89000,70000]
df9 = pd.DataFrame({'Store': storeList,
                         'Location':locationList,
                          'Sales':salesList})
df9['Rank_Sales'] = df9['Sales'].rank(ascending=False)
df9
# Out:
#   Store   Location   Sales  Rank_Sales
# 0     A     Mumbai   40000        10.0
# 1     B       Pune   45000         9.0
# 2     A  Hyderabad   50000         8.0
# 3     C     Mumbai   90000         2.0
# 4     D       Pune   89000         3.5
# 5     A      Delhi   87000         5.0
# 6     D  Hyderabad   85000         6.0
# 7     A       Pune  780000         1.0
# 8     C     Mumbai   89000         3.5
# 9     B       Pune   70000         7.0
